# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('Advertising Budget and Sales.csv')
X=df[['TV Ad Budget','Radio Ad Budget','Newspaper Ad Budget']]
Y=df['Sales']
df.corr()
# Out:
#                      Unnamed: 0  TV Ad Budget  Radio Ad Budget  \
# Unnamed: 0             1.000000      0.017715        -0.110680
# TV Ad Budget           0.017715      1.000000         0.054809
# Radio Ad Budget       -0.110680      0.054809         1.000000
# Newspaper Ad Budget   -0.154944      0.056648         0.354104
# Sales                 -0.051616      0.782224         0.576223
#
#                      Newspaper Ad Budget     Sales
# Unnamed: 0                     -0.154944 -0.051616
# TV Ad Budget                    0.056648  0.782224
# Radio Ad Budget                 0.354104  0.576223
# Newspaper Ad Budget             1.000000  0.228299
# Sales                           0.228299  1.000000

# %%
plt.scatter(df[['TV Ad Budget']],df['Sales'],label='TV')
plt.scatter(df[['Radio Ad Budget']],df['Sales'],label='Radio')
plt.scatter(df[['Newspaper Ad Budget']],df['Sales'],label='Newspaper')
plt.legend()
plt.show()

# %% [markdown]
# syntax of train_test_split
#
# Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,train_size=0.8,random_state=42)
#
# train_test_split(X,Y,train_size=0.8)--> Returns list of 4 values

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,train_size=0.8,random_state=42)

# %%
train_test_split(X,Y,train_size=0.8,random_state=42)
# Out:
# [     TV Ad Budget  Radio Ad Budget  Newspaper Ad Budget
#  79          116.0              7.7                 23.1
#  197         177.0              9.3                  6.4
#  38           43.1             26.7                 35.1
#  24           62.3             12.6                 18.3
#  122         224.0              2.4                 15.6
#  ..            ...              ...                  ...
#  106          25.0             11.0                 29.7
#  14          204.1             32.9                 46.0
#  92          217.7             33.5                 59.0
#  179         165.6             10.0                 17.6
#  102         280.2             10.1                 21.4
#
#  [160 rows x 3 columns],
#       TV Ad Budget  Radio Ad Budget  Newspaper Ad Budget
#  95          163.3             31.6                 52.9
#  15          195.4             47.7                 52.9
#  30          292.9             28.3                 43.2
# ...

# %%
Xtrain
# Out:
#      TV Ad Budget  Radio Ad Budget  Newspaper Ad Budget
# 79          116.0              7.7                 23.1
# 197         177.0              9.3                  6.4
# 38           43.1             26.7                 35.1
# 24           62.3             12.6                 18.3
# 122         224.0              2.4                 15.6
# ..            ...              ...                  ...
# 106          25.0             11.0                 29.7
# 14          204.1             32.9                 46.0
# 92          217.7             33.5                 59.0
# 179         165.6             10.0                 17.6
# 102         280.2             10.1                 21.4
#
# [160 rows x 3 columns]

# %%
model=LinearRegression()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
Ytrain
# Out:
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 160, dtype: float64

# %%
Ypred=model.predict(Xtrain)
Ypred
# Out:
# array([ 9.67530328, 12.78592082,  9.90868103,  8.14651887, 13.6264571 ,
#         5.37034248,  9.14402389, 14.16607293,  8.76480262, 11.59870739,
#        15.30509593, 11.97093887, 12.47834763, 10.57717411,  6.5707774 ,
#         9.90298206,  9.48964097, 24.11860723,  7.60769238, 12.63571716,
#        17.9415563 , 15.33707782, 11.3460929 , 10.57712073, 17.00682618,
#         6.82006767, 21.59580326,  6.05162411,  9.99922965, 11.45348627,
#         9.33981296,  6.599669  , 14.94678206, 17.2959832 , 15.56609348,
#        16.40377623, 14.98951429, 19.67547632, 13.87595844, 21.14027498,
#        12.30767078, 13.81190223,  8.87338673, 17.07644223,  8.42401933,
#        15.18140789, 13.55914568, 23.40590052, 12.4891591 , 22.89067208,
#         6.4891503 , 18.39902932, 23.24248685, 18.86426829, 17.28512918,
#        16.49530044, 12.39914823, 11.72975995, 17.05167344, 14.41010605,
#        13.18867186,  7.63888314, 19.24986927,  9.70853872, 19.69293106,
# ...

# %%
error=Ytrain-Ypred
error
# Out:
# 79     1.324697
# 197    0.014079
# 38     0.191319
# 24     1.553481
# 122   -2.026457
#          ...
# 106    1.073978
# 14     0.565634
# 92     0.243604
# 179    0.215445
# 102   -2.844094
# Name: Sales, Length: 160, dtype: float64
